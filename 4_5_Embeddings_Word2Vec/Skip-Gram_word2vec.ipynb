# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:04, 483KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

counts = Counter(int_words)
index = 0
        
removal_thres = 1e-5
total_word_count = len(int_words)
        
def remove_it(thresh, count):
    prob = 1-((thresh)/count)**0.5
    return prob
    
frequencies = {word: count/total_word_count for word, count in counts.items()}

for word, count in counts.items():
    print("{} {} {}".format(word, int_to_vocab[word], frequencies[word]))
    index += 1
    if index==10:
        break

        
## Your code here
train_words = [word for word in int_words if random.random() < remove_it(removal_thres, frequencies[word])]  # The final subsampled word list

print("Recuded length / Original length: {} {}".format(len(train_words),len(int_words)))
# Out:
# 0 the 0.06363056866243233
# 1 of 0.035590868169662254
# 2 and 0.02497686084294695
# 3 one 0.02468520465002486
# 4 in 0.022313407330276328
# 5 a 0.01953604903516954
# 6 to 0.018966704972645167
# 7 zero 0.015885220908433802
# 8 nine 0.015013249823942174
# 9 two 0.011548985740859786
# Recuded length / Original length: 16680599 12055282

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    max_range = random.randint(1,window_size+1)
    start = idx-max_range if idx>=max_range else 0
    end = idx + max_range
    
    word_set = set(words[start:idx] + words[idx+1:end+1])
    
    return list(word_set)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200  # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(initial_value=tf.random_uniform(shape=(n_vocab, n_embedding), minval=-1.0, maxval=1.0), name='embedding')  # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)  # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.truncated_normal((n_vocab, n_embedding), stddev=0.1) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 9.1453 0.2501 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 9.0574 0.2445 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 9.0125 0.2364 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 9.0415 0.2245 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 8.9270 0.2240 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 8.8491 0.2417 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 8.8578 0.2227 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 8.7892 0.2362 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 8.6569 0.2414 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 8.6036 0.2288 sec/batch
# Nearest to this: winthrop, gynecologists, boone, lan, residence, revivalist, espouses, crescent,
# Nearest to had: inexplicable, gentrification, debugging, charlize, jackass, gunboats, mincha, immaturity,
# Nearest to use: minimally, bitmaps, paraclete, mccracken, malo, irenaeus, assai, smog,
# Nearest to at: nursery, malayalam, kaufmann, themed, pais, olanzapine, uso, misbehavior,
# Nearest to four: determinate, rodriguez, sms, huey, spingarn, resets, cements, henotheistic,
# Nearest to all: minocycline, unsafe, faun, surrealism, lott, rivalries, mcpherson, learn,
# Nearest to can: livius, drier, stringent, guiscard, boris, specificity, jameson, quisling,
# Nearest to d: ibo, ashtoreth, wet, huron, consult, philosophie, fault, penning,
# Nearest to hold: militarism, aspergillus, computing, outlawing, newbies, sikhs, doug, dissipative,
# Nearest to road: galla, micrometres, inoculate, aon, facet, policia, readings, cooperatively,
# Nearest to running: reprise, nnp, scuola, dipyramid, monaro, birthplace, saxophonist, cma,
# Nearest to quite: christoph, rookies, equuleus, meaningfully, rid, fuhito, laodicea, menhir,
# Nearest to joseph: monotone, mario, halcyon, ryle, kylix, arya, wallowing, kernel,
# Nearest to professional: sacagawea, loyola, masochism, consultative, antiquarian, dockyard, popularised, eram,
# Nearest to primarily: typhus, circonscription, regimental, godley, mangeshkar, unfettered, globus, boston,
# Nearest to accepted: eutelsat, imlay, mongolians, corruption, speak, ashram, verbs, haec,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 8.5351 0.2461 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 8.5029 0.2306 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 8.4199 0.2484 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 8.3304 0.2345 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 8.2693 0.2346 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 8.1804 0.2365 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 8.1173 0.2358 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 8.0678 0.2348 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 8.0109 0.2337 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 7.9450 0.2350 sec/batch
# Nearest to this: winthrop, gynecologists, boone, residence, childbirth, lan, reboot, crescent,
# Nearest to had: inexplicable, gentrification, debugging, jackass, charlize, gunboats, mincha, gallon,
# Nearest to use: minimally, paraclete, bitmaps, mccracken, malo, smog, assai, irenaeus,
# Nearest to at: nursery, kaufmann, malayalam, themed, pais, olanzapine, uso, penetrating,
# Nearest to four: determinate, rodriguez, sms, spingarn, huey, resets, cements, xls,
# Nearest to all: minocycline, surrealism, unsafe, faun, lott, rivalries, listed, learn,
# Nearest to can: livius, drier, specificity, guiscard, stringent, boris, quisling, thrax,
# Nearest to d: ibo, ashtoreth, huron, wet, consult, philosophie, bolyai, fault,
# Nearest to hold: aspergillus, militarism, computing, outlawing, newbies, doug, dissipative, sikhs,
# Nearest to road: galla, inoculate, aon, facet, micrometres, readings, cooperatively, centralism,
# Nearest to running: reprise, nnp, scuola, dipyramid, monaro, birthplace, abstractions, rhinoceros,
# Nearest to quite: christoph, rookies, equuleus, meaningfully, rid, laodicea, fuhito, menhir,
# Nearest to joseph: monotone, mario, halcyon, kylix, ryle, arya, tsonga, euclid,
# Nearest to professional: loyola, sacagawea, dockyard, antiquarian, consultative, masochism, popularised, coanda,
# Nearest to primarily: typhus, circonscription, regimental, godley, mangeshkar, boston, globus, invents,
# Nearest to accepted: eutelsat, imlay, mongolians, speak, verbs, haec, corruption, feldspars,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 7.8730 0.2308 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 7.8339 0.2193 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 7.7814 0.2424 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 7.7214 0.2298 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 7.6304 0.2487 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 7.5711 0.2514 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 7.5087 0.2486 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 7.4020 0.2451 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 7.3681 0.2550 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 7.3677 0.2536 sec/batch
# Nearest to this: gynecologists, boone, winthrop, lan, calories, linguistically, bosnians, lactantius,
# Nearest to had: inexplicable, gentrification, debugging, charlize, jackass, gunboats, immaturity, mincha,
# Nearest to use: minimally, bitmaps, paraclete, mccracken, malo, smog, assai, mastercard,
# Nearest to at: kaufmann, nursery, malayalam, uso, themed, pais, olanzapine, cope,
# Nearest to four: determinate, rodriguez, huey, spingarn, sms, henotheistic, stanford, resets,
# Nearest to all: minocycline, surrealism, faun, unsafe, lott, surrender, screenname, listed,
# Nearest to can: livius, drier, specificity, guiscard, quisling, boris, stringent, pellets,
# Nearest to d: ibo, ashtoreth, huron, consult, philosophie, fault, wet, bolyai,
# Nearest to hold: aspergillus, militarism, newbies, doug, dissipative, computing, horns, commodities,
# Nearest to road: galla, aon, micrometres, facet, inoculate, readings, centralism, earthbound,
# Nearest to running: nnp, reprise, scuola, dipyramid, monaro, cma, abstractions, birthplace,
# Nearest to quite: christoph, rookies, equuleus, meaningfully, rid, laodicea, leroux, scharnhorst,
# Nearest to joseph: monotone, mario, halcyon, ryle, kylix, arya, euclid, tsonga,
# Nearest to professional: sacagawea, loyola, dockyard, masochism, consultative, antiquarian, popularised, cana,
# Nearest to primarily: typhus, circonscription, regimental, godley, mangeshkar, chipmunk, invents, xa,
# Nearest to accepted: eutelsat, imlay, mongolians, verbs, speak, feldspars, ashram, ctesias,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 7.2546 0.2552 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 7.2489 0.2465 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 7.1399 0.2499 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 7.1118 0.2297 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 7.0143 0.2348 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 6.9261 0.2454 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 6.9605 0.2436 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 6.8804 0.2532 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 6.8037 0.2349 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 6.7745 0.2458 sec/batch
# Nearest to this: gynecologists, lan, winthrop, childbirth, outage, revivalist, boone, reboot,
# Nearest to had: gentrification, inexplicable, charlize, jackass, debugging, gunboats, mincha, equ,
# Nearest to use: minimally, bitmaps, paraclete, mccracken, smog, malo, assai, mastercard,
# Nearest to at: kaufmann, malayalam, nursery, themed, uso, pais, bayesian, penetrating,
# Nearest to four: rodriguez, determinate, spingarn, huey, sms, stanford, henotheistic, josep,
# Nearest to all: minocycline, surrealism, faun, unsafe, listed, rivalries, todd, surrender,
# Nearest to can: livius, guiscard, drier, specificity, stringent, boris, pellets, almighty,
# Nearest to d: ibo, ashtoreth, huron, wet, consult, bolyai, philosophie, penning,
# Nearest to hold: aspergillus, militarism, doug, sikhs, newbies, commodities, outlawing, dissipative,
# Nearest to road: galla, facet, aon, micrometres, readings, inoculate, earthbound, centralism,
# Nearest to running: reprise, nnp, scuola, monaro, abstractions, dipyramid, lughnasadh, cma,
# Nearest to quite: christoph, equuleus, rookies, rid, meaningfully, laodicea, leroux, draper,
# Nearest to joseph: monotone, mario, halcyon, arya, ryle, kylix, euclid, wallowing,
# Nearest to professional: loyola, sacagawea, consultative, masochism, dockyard, antiquarian, popularised, cana,
# Nearest to primarily: typhus, circonscription, regimental, godley, chipmunk, globus, wow, edmonton,
# Nearest to accepted: eutelsat, imlay, mongolians, speak, verbs, feldspars, haec, ctesias,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 6.6967 0.2445 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 6.6426 0.2421 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 6.6472 0.2639 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 6.5866 0.2371 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 6.5262 0.2337 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 6.4832 0.2458 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 6.4377 0.2088 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 6.3283 0.2282 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 6.3277 0.2343 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 6.2487 0.2213 sec/batch
# Nearest to this: gynecologists, lan, bosnians, firma, winthrop, crescent, outage, linguistically,
# Nearest to had: inexplicable, charlize, gentrification, debugging, jackass, immaturity, equ, impermeable,
# Nearest to use: minimally, paraclete, bitmaps, smog, mccracken, malo, mastercard, assai,
# Nearest to at: kaufmann, malayalam, nursery, themed, uso, qana, pais, katie,
# Nearest to four: determinate, stanford, rodriguez, huey, sms, henotheistic, spingarn, josep,
# Nearest to all: minocycline, unsafe, faun, listed, surrender, trinkets, forge, rivalries,
# Nearest to can: guiscard, specificity, livius, drier, stringent, boris, zukor, relationships,
# Nearest to d: ashtoreth, ibo, huron, bolyai, wet, globe, consult, philosophie,
# Nearest to hold: aspergillus, doug, militarism, outlawing, sikhs, dissipative, newbies, smallness,
# Nearest to road: galla, aon, facet, micrometres, inoculate, readings, sanl, alston,
# Nearest to running: reprise, nnp, scuola, monaro, abstractions, diefenbaker, cma, dipyramid,
# Nearest to quite: christoph, equuleus, rookies, rid, meaningfully, laodicea, menhir, galveston,
# Nearest to joseph: monotone, mario, halcyon, ryle, arya, euclid, wallowing, retina,
# Nearest to professional: loyola, consultative, sacagawea, masochism, antiquarian, dockyard, beside, popularised,
# Nearest to primarily: typhus, circonscription, regimental, chipmunk, godley, edmonton, wow, globus,
# Nearest to accepted: eutelsat, imlay, mongolians, speak, be, feldspars, haec, ctesias,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 6.1646 0.2236 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 6.1304 0.2198 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 6.1256 0.2181 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 6.0478 0.2187 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 5.9986 0.2172 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 5.9630 0.2206 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 5.9305 0.2186 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 5.8669 0.2187 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 5.8353 0.2178 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 5.8439 0.2177 sec/batch
# Nearest to this: lan, linguistically, imaginative, firma, gynecologists, bosnians, lactantius, diminished,
# Nearest to had: debugging, inexplicable, charlize, jackass, gentrification, immaturity, vast, mincha,
# Nearest to use: minimally, bitmaps, smog, paraclete, mccracken, malo, mastercard, irenaeus,
# Nearest to at: kaufmann, themed, malayalam, qana, nursery, uso, misbehavior, pais,
# Nearest to four: determinate, stanford, rodriguez, huey, sms, henotheistic, josep, gemological,
# Nearest to all: minocycline, faun, listed, unsafe, gallant, iktinos, rivalries, jerusalem,
# Nearest to can: guiscard, drier, livius, stringent, deal, boris, specificity, zukor,
# Nearest to d: ashtoreth, ibo, huron, bolyai, wet, philosophie, globe, bison,
# Nearest to hold: aspergillus, dissipative, newbies, outlawing, militarism, smallness, doug, sikhs,
# Nearest to road: galla, aon, facet, micrometres, inoculate, sanl, readings, alston,
# Nearest to running: reprise, nnp, scuola, abstractions, monaro, dipyramid, cma, diefenbaker,
# Nearest to quite: christoph, equuleus, rookies, rid, fuhito, galveston, meaningfully, laodicea,
# Nearest to joseph: monotone, mario, halcyon, arya, ryle, wallowing, pronouncements, kernel,
# Nearest to professional: loyola, consultative, masochism, sacagawea, dockyard, popularised, antiquarian, beside,
# Nearest to primarily: typhus, chipmunk, circonscription, regimental, godley, edmonton, wow, mangeshkar,
# Nearest to accepted: eutelsat, imlay, mongolians, verbs, feldspars, speak, be, dignities,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 5.7787 0.2215 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 5.7828 0.2184 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 5.7081 0.2181 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 5.7156 0.2135 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 5.5749 0.2526 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 5.5627 0.2583 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 5.5211 0.2598 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 5.4939 0.2615 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 5.4864 0.2578 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 5.4224 0.2509 sec/batch
# Nearest to this: lan, reboot, imaginative, linguistically, amputation, crescent, rref, srinivasa,
# Nearest to had: inexplicable, debugging, charlize, immaturity, gentrification, jackass, nonterminals, equ,
# Nearest to use: smog, minimally, paraclete, bitmaps, malo, mccracken, mastercard, astronomia,
# Nearest to at: uso, bloom, almaty, nursery, meritocracy, anthropic, katie, kaufmann,
# Nearest to four: determinate, stanford, rodriguez, satirically, sms, gemological, josep, huey,
# Nearest to all: minocycline, surrealism, gallant, listed, unsafe, faun, resurrect, iktinos,
# Nearest to can: guiscard, stringent, livius, deal, drier, thrax, pellets, boris,
# Nearest to d: ashtoreth, huron, ibo, bolyai, wet, bison, consult, philosophie,
# Nearest to hold: aspergillus, smallness, militarism, outlawing, sikhs, newbies, dissipative, commodities,
# Nearest to road: galla, facet, aon, readings, inoculate, micrometres, earthbound, sanl,
# Nearest to running: reprise, nnp, scuola, abstractions, monaro, dipyramid, diefenbaker, cma,
# Nearest to quite: christoph, equuleus, rookies, meaningfully, fuhito, rid, galveston, laodicea,
# Nearest to joseph: monotone, mario, halcyon, arya, ryle, wallowing, retina, happens,
# Nearest to professional: loyola, consultative, masochism, dockyard, antiquarian, beside, sacagawea, popularised,
# Nearest to primarily: typhus, chipmunk, circonscription, regimental, godley, mangeshkar, wow, edmonton,
# Nearest to accepted: eutelsat, imlay, mongolians, dignities, verbs, ashram, ctesias, feldspars,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 5.3643 0.2620 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 5.3368 0.2527 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 5.3176 0.2525 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 5.2875 0.2524 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 5.2756 0.2566 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 5.2094 0.2595 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 5.1859 0.2502 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 5.1506 0.2498 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 5.1612 0.2483 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 5.1194 0.2588 sec/batch
# Nearest to this: lan, linguistically, appalachia, gynecologists, zoom, pott, amputation, srinivasa,
# Nearest to had: inexplicable, debugging, equ, immaturity, charlize, gentrification, gluon, nonterminals,
# Nearest to use: paraclete, minimally, bitmaps, malo, smog, mccracken, mastercard, interrelationships,
# Nearest to at: bloom, sulfuric, meritocracy, antarctic, uso, lightest, the, ligands,
# Nearest to four: determinate, rodriguez, stanford, satirically, sms, arsenal, vertigo, spingarn,
# Nearest to all: listed, iktinos, faun, gallant, unsafe, surrealism, minocycline, mn,
# Nearest to can: guiscard, stringent, drier, thrax, interconnects, pellets, deal, specificity,
# Nearest to d: ashtoreth, huron, ibo, wet, bison, bolyai, sanchez, peppered,
# Nearest to hold: aspergillus, militarism, smallness, madhya, outlawing, commodities, newbies, doug,
# Nearest to road: galla, aon, readings, facet, inoculate, earthbound, micrometres, drenched,
# Nearest to running: reprise, nnp, scuola, abstractions, monaro, dipyramid, diefenbaker, yup,
# Nearest to quite: christoph, equuleus, fuhito, meaningfully, rookies, rid, galveston, laodicea,
# Nearest to joseph: monotone, mario, halcyon, arya, ryle, happens, tsonga, retina,
# Nearest to professional: loyola, masochism, dockyard, consultative, beside, antiquarian, sacagawea, grasse,
# Nearest to primarily: typhus, chipmunk, circonscription, regimental, mangeshkar, godley, edmonton, wow,
# Nearest to accepted: eutelsat, imlay, ashram, mongolians, haec, ctesias, verbs, speak,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 5.1113 0.2568 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 5.0548 0.2550 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 5.0684 0.2592 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 5.0769 0.2484 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 5.0139 0.2503 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 5.0151 0.2538 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.9971 0.2561 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.9705 0.2542 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.9697 0.2545 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.9659 0.2583 sec/batch
# Nearest to this: from, virginity, linguistically, copyrighted, lan, childbirth, of, pott,
# Nearest to had: inexplicable, equ, debugging, gentrification, immaturity, nonterminals, gluon, charlize,
# Nearest to use: bitmaps, paraclete, minimally, smog, history, mastercard, malo, mccracken,
# Nearest to at: lightest, antarctic, astral, bloom, qana, the, coates, meritocracy,
# Nearest to four: determinate, cultures, six, rodriguez, arsenal, dagbladet, agitating, gemological,
# Nearest to all: listed, iktinos, resurrect, gallant, minocycline, unsafe, coefficients, wisdom,
# Nearest to can: guiscard, drier, stringent, almighty, livius, labs, hasidic, jameson,
# Nearest to d: ashtoreth, huron, ibo, wet, bolyai, peppered, sanchez, bison,
# Nearest to hold: aspergillus, militarism, commodities, smallness, newbies, outlawing, sikhs, downy,
# Nearest to road: galla, readings, facet, inoculate, aon, micrometres, earthbound, sanl,
# Nearest to running: reprise, nnp, scuola, abstractions, diefenbaker, monaro, dipyramid, saxophonist,
# Nearest to quite: christoph, fuhito, equuleus, meaningfully, rookies, asw, galveston, draper,
# Nearest to joseph: monotone, halcyon, mario, arya, ryle, oktoberfest, pronouncements, tsonga,
# Nearest to professional: loyola, dockyard, beside, masochism, grasse, antiquarian, popularised, preside,
# Nearest to primarily: typhus, chipmunk, circonscription, regimental, mangeshkar, wow, sidney, godley,
# Nearest to accepted: eutelsat, imlay, haec, ashram, mongolians, ctesias, verbs, fl,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 5.1256 0.2445 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.9873 0.2537 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.9570 0.2957 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.9103 0.2627 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.8695 0.2574 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.8759 0.2557 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.8590 0.2597 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.8547 0.2587 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.8076 0.2559 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.7923 0.2489 sec/batch
# Nearest to this: a, of, the, and, from, by, as, on,
# Nearest to had: inexplicable, equ, nonterminals, gentrification, hanks, hardship, immaturity, debugging,
# Nearest to use: with, smog, the, bitmaps, paraclete, history, minimally, mastercard,
# Nearest to at: of, the, and, a, in, s, was, as,
# Nearest to four: six, vertigo, determinate, zero, cse, pottery, cultures, grabs,
# Nearest to all: order, gallant, iktinos, listed, resurrect, magma, unsafe, beiderbecke,
# Nearest to can: guiscard, livius, drier, thrax, stringent, labs, jameson, parsing,
# Nearest to d: huron, ibo, ashtoreth, wet, fandango, peppered, bolyai, fault,
# Nearest to hold: aspergillus, militarism, commodities, smallness, sena, sikhs, outlawing, newbies,
# Nearest to road: galla, readings, wandered, facet, exceeding, aon, alston, micrometres,
# Nearest to running: reprise, nnp, scuola, abstractions, lughnasadh, beleaguered, diefenbaker, intersects,
# Nearest to quite: fuhito, christoph, meaningfully, equuleus, draper, rookies, laodicea, vain,
# Nearest to joseph: monotone, mario, halcyon, arya, ryle, pronouncements, eugen, formulario,
# Nearest to professional: loyola, dockyard, beside, masochism, preside, grasse, antiquarian, funded,
# Nearest to primarily: typhus, chipmunk, circonscription, mangeshkar, edmonton, sidney, wow, godley,
# Nearest to accepted: eutelsat, imlay, mongolians, ashram, haec, verbs, ctesias, karsh,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.8442 0.2454 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.8207 0.2204 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.8033 0.2194 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.7892 0.2193 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.7913 0.2209 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.7613 0.2196 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.7734 0.2207 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.8003 0.2269 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.7644 0.2435 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.7620 0.2373 sec/batch
# Nearest to this: a, that, and, of, the, its, is, in,
# Nearest to had: nonterminals, equ, tolkien, millilitre, eelam, inexplicable, hats, lleida,
# Nearest to use: malo, smog, minimally, bitmaps, paraclete, mastercard, grapheme, michal,
# Nearest to at: the, in, a, to, of, and, s, was,
# Nearest to four: six, zero, determinate, agitating, one, vertigo, three, weiner,
# Nearest to all: and, listed, iktinos, greasy, magma, screenname, gallant, platter,
# Nearest to can: guiscard, thrax, baton, livius, stringent, this, stuart, pellets,
# Nearest to d: ibo, huron, ashtoreth, wet, fandango, worldwide, peppered, anna,
# Nearest to hold: aspergillus, militarism, smallness, outlawing, detractors, consultations, madhya, dissipative,
# Nearest to road: galla, readings, earthbound, wandered, phoneme, sanl, exceeding, micrometres,
# Nearest to running: reprise, lughnasadh, scuola, nnp, beleaguered, outfield, blanket, intersects,
# Nearest to quite: fuhito, meaningfully, christoph, equuleus, draper, vain, rookies, galveston,
# Nearest to joseph: monotone, mario, halcyon, ryle, arya, eugen, pronouncements, euclid,
# Nearest to professional: loyola, dockyard, beside, masochism, funded, grasse, preside, antiquarian,
# Nearest to primarily: typhus, mangeshkar, circonscription, edmonton, chipmunk, regimental, wow, sidney,
# Nearest to accepted: imlay, eutelsat, mongolians, verbs, haec, ctesias, feldspars, speak,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.7528 0.2426 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.7416 0.2444 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.7542 0.2416 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.7424 0.2537 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.7082 0.2239 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.7218 0.2371 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.6963 0.2263 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.6560 0.2279 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.6948 0.2310 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.6922 0.2323 sec/batch
# Nearest to this: of, the, a, and, by, in, to, on,
# Nearest to had: eelam, was, blackletter, calixto, while, to, his, as,
# Nearest to use: to, mastercard, paraclete, smog, bitmaps, psychoacoustics, and, known,
# Nearest to at: a, s, the, also, in, was, and, as,
# Nearest to four: six, zero, three, one, two, eight, five, nine,
# Nearest to all: and, the, composers, also, of, a, to, this,
# Nearest to can: a, and, guiscard, of, it, that, livius, keyser,
# Nearest to d: ashtoreth, huron, wet, ibo, sojourner, blackheath, stagnant, philosophie,
# Nearest to hold: aspergillus, militarism, smallness, downy, sena, bilbo, outlawing, statics,
# Nearest to road: galla, alston, readings, wandered, micrometres, earthbound, phoneme, grandmother,
# Nearest to running: reprise, lughnasadh, scuola, outfield, diefenbaker, wikicities, nnp, blanket,
# Nearest to quite: fuhito, meaningfully, christoph, equuleus, draper, vain, microscope, rookies,
# Nearest to joseph: monotone, mario, halcyon, ryle, eugen, deutsch, euclid, arya,
# Nearest to professional: loyola, dockyard, beside, masochism, preside, grasse, antiquarian, grief,
# Nearest to primarily: typhus, mangeshkar, edmonton, circonscription, tumulus, wow, chipmunk, sidney,
# Nearest to accepted: imlay, eutelsat, mongolians, haec, speak, corruption, ashram, ctesias,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.6950 0.1074 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.6809 0.2336 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.6881 0.2330 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.6606 0.2274 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.6610 0.2295 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.6471 0.2356 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.6166 0.2356 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.6151 0.2359 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.5950 0.2262 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.6371 0.2345 sec/batch
# Nearest to this: the, in, and, of, to, a, is, that,
# Nearest to had: was, eelam, to, were, his, which, populous, and,
# Nearest to use: paraclete, minimally, mastercard, unfiltered, psychoacoustics, known, grapheme, many,
# Nearest to at: in, the, of, and, to, was, as, a,
# Nearest to four: six, one, zero, three, two, eight, five, nine,
# Nearest to all: and, the, is, a, as, which, to, of,
# Nearest to can: be, a, this, there, society, livius, guiscard, muppet,
# Nearest to d: huron, ashtoreth, wet, sojourner, stagnant, ibo, blackheath, worldwide,
# Nearest to hold: aspergillus, militarism, doug, bilbo, detractors, downy, smallness, computing,
# Nearest to road: earthbound, galla, alston, readings, grandmother, micrometres, aon, wandered,
# Nearest to running: reprise, scuola, outfield, wikicities, beleaguered, lughnasadh, blanket, saxophonist,
# Nearest to quite: fuhito, christoph, equuleus, meaningfully, draper, laodicea, dianetic, rookies,
# Nearest to joseph: monotone, mario, analysed, ryle, halcyon, deutsch, oktoberfest, nationalized,
# Nearest to professional: loyola, dockyard, beside, grief, motu, funded, grasse, midfielders,
# Nearest to primarily: typhus, mangeshkar, circonscription, sidney, tumulus, chipmunk, edmonton, godley,
# Nearest to accepted: imlay, haec, eutelsat, mongolians, verbs, ctesias, feldspars, rollercoaster,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.6177 0.2363 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.6385 0.2334 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.6151 0.2214 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.5635 0.2253 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.6370 0.2200 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.6003 0.2185 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.6140 0.2377 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.6079 0.2182 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.5932 0.2262 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.5989 0.2173 sec/batch
# Nearest to this: to, that, the, of, in, a, is, be,
# Nearest to had: was, his, eelam, populous, wilma, the, he, lleida,
# Nearest to use: psychoacoustics, paraclete, mastercard, many, known, conveyor, grapheme, crap,
# Nearest to at: the, and, of, in, as, by, a, to,
# Nearest to four: six, one, three, five, zero, two, eight, seven,
# Nearest to all: to, and, the, a, which, of, from, is,
# Nearest to can: be, to, is, that, a, by, this, from,
# Nearest to d: huron, wet, ashtoreth, sojourner, stagnant, tupolev, blackheath, ibo,
# Nearest to hold: militarism, aspergillus, bilbo, doug, computing, sena, sikhs, detractors,
# Nearest to road: galla, grandmother, earthbound, micrometres, alston, wandered, aon, facet,
# Nearest to running: reprise, genres, wikicities, scuola, monaro, saxophonist, beleaguered, lughnasadh,
# Nearest to quite: fuhito, equuleus, laodicea, christoph, comintern, meaningfully, microscope, rookies,
# Nearest to joseph: monotone, mario, ryle, analysed, mission, halcyon, deutsch, marries,
# Nearest to professional: loyola, beside, dockyard, grief, midfielders, antiquarian, chapman, ange,
# Nearest to primarily: typhus, mangeshkar, circonscription, tumulus, sidney, edmonton, buccaneer, corpus,
# Nearest to accepted: imlay, haec, eutelsat, verbs, tempted, mongolians, ctesias, rollercoaster,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.5848 0.2304 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.5823 0.2212 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.5761 0.2268 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.5516 0.2281 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.5470 0.2337 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.5887 0.2422 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.5751 0.2442 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.5783 0.2404 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.6101 0.2555 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.5789 0.2186 sec/batch
# Nearest to this: that, is, as, the, for, a, to, it,
# Nearest to had: was, his, the, with, to, in, a, by,
# Nearest to use: be, as, a, or, paltrow, other, paraclete, and,
# Nearest to at: the, with, of, a, in, to, and, by,
# Nearest to four: six, five, one, three, two, zero, eight, nine,
# Nearest to all: the, in, of, and, is, by, a, has,
# Nearest to can: be, or, have, to, a, is, other, are,
# Nearest to d: huron, wet, ashtoreth, sojourner, stagnant, blackheath, ibo, tupolev,
# Nearest to hold: militarism, aspergillus, bilbo, culture, doug, sikhs, computing, delegation,
# Nearest to road: galla, earthbound, micrometres, grandmother, facet, wet, aon, wandered,
# Nearest to running: reprise, genres, christians, lughnasadh, scuola, beleaguered, saxophonist, politico,
# Nearest to quite: equuleus, fuhito, microscope, comintern, rambam, laodicea, streamline, meaningfully,
# Nearest to joseph: monotone, mario, loyal, ryle, mission, halcyon, analysed, deutsch,
# Nearest to professional: loyola, dockyard, grief, beside, antiquarian, ange, ammonite, nonpolar,
# Nearest to primarily: typhus, mangeshkar, edmonton, corpus, sidney, echomail, circonscription, buccaneer,
# Nearest to accepted: imlay, haec, mongolians, eutelsat, rollercoaster, verbs, ctesias, undergarments,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.5700 0.2361 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.5770 0.2408 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.5722 0.2407 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.5647 0.2540 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.5438 0.2515 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.5428 0.2336 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.5938 0.2375 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.5519 0.2336 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.5357 0.2332 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.5465 0.2423 sec/batch
# Nearest to this: as, to, that, for, the, be, and, is,
# Nearest to had: was, the, by, were, his, as, and, to,
# Nearest to use: is, be, or, first, it, hampers, known, of,
# Nearest to at: of, the, to, that, in, and, by, as,
# Nearest to four: five, six, three, two, one, eight, zero, nine,
# Nearest to all: the, and, in, which, to, is, that, a,
# Nearest to can: is, a, or, be, to, as, which, the,
# Nearest to d: huron, wet, ashtoreth, sojourner, blackheath, tupolev, stagnant, beckenbauer,
# Nearest to hold: aspergillus, militarism, doug, computing, detractors, bilbo, culture, sena,
# Nearest to road: galla, facet, grandmother, earthbound, subcontinent, aon, wet, hybridized,
# Nearest to running: reprise, christians, politico, aleksey, outfield, lughnasadh, intersects, scuola,
# Nearest to quite: fuhito, laodicea, microscope, rambam, equuleus, nic, toilet, comintern,
# Nearest to joseph: monotone, mario, analysed, mission, arya, loyal, deutsch, halcyon,
# Nearest to professional: loyola, dockyard, ange, grief, munition, antiquarian, nonpolar, ammonite,
# Nearest to primarily: typhus, mangeshkar, wow, buccaneer, echomail, orbit, camilla, edmonton,
# Nearest to accepted: imlay, haec, eutelsat, fart, mongolians, verbs, undergarments, ctesias,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.5254 0.2250 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.5332 0.2224 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.5241 0.2198 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.5253 0.2218 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.5321 0.2410 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.5313 0.2356 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.5298 0.2374 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.5086 0.2321 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.5135 0.2317 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.5108 0.2306 sec/batch
# Nearest to this: as, in, and, is, to, the, that, be,
# Nearest to had: was, the, to, he, of, and, that, his,
# Nearest to use: it, is, of, system, resembles, be, its, known,
# Nearest to at: the, in, of, and, is, a, to, on,
# Nearest to four: five, one, six, three, eight, two, seven, zero,
# Nearest to all: to, the, that, on, as, a, of, which,
# Nearest to can: is, be, are, a, to, or, as, that,
# Nearest to d: huron, conjecture, sojourner, inuit, ashtoreth, recharged, one, wet,
# Nearest to hold: aspergillus, bilbo, computing, doug, militarism, sikhs, sena, flier,
# Nearest to road: grandmother, facet, subcontinent, earthbound, micrometres, bahr, galla, grenada,
# Nearest to running: reprise, christians, aleksey, enlightened, imitations, outfield, politico, lughnasadh,
# Nearest to quite: rambam, microscope, fuhito, toilet, laodicea, equuleus, comintern, galveston,
# Nearest to joseph: monotone, mario, arya, mission, halcyon, analysed, nationalized, although,
# Nearest to professional: loyola, dockyard, ange, grief, munition, nonpolar, superhero, antiquarian,
# Nearest to primarily: mangeshkar, typhus, edmonton, echomail, wow, camilla, buccaneer, adventures,
# Nearest to accepted: imlay, haec, rollercoaster, verbs, eutelsat, mongolians, fart, namek,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.5058 0.2328 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.5015 0.2226 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.5177 0.2204 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.4910 0.2282 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.5015 0.2188 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.4749 0.2227 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.4926 0.2252 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.4861 0.2439 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.5073 0.2282 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.5257 0.2261 sec/batch
# Nearest to this: to, the, is, that, of, and, as, in,
# Nearest to had: to, was, and, been, were, for, in, the,
# Nearest to use: known, mamre, ingui, its, renouncing, chunks, irrespective, ucayali,
# Nearest to at: in, the, to, of, from, on, and, by,
# Nearest to four: one, five, six, three, eight, seven, two, nine,
# Nearest to all: to, the, and, only, a, of, that, for,
# Nearest to can: is, be, are, it, a, not, which, that,
# Nearest to d: huron, ashtoreth, conjecture, cpr, zaitsev, recharged, whistleblower, sojourner,
# Nearest to hold: aspergillus, bilbo, came, flier, sikhs, neogene, doug, computing,
# Nearest to road: grandmother, earthbound, micrometres, gon, subcontinent, facet, grenada, alston,
# Nearest to running: christians, reprise, aleksey, enlightened, monaro, yup, lughnasadh, imitations,
# Nearest to quite: laodicea, fuhito, microscope, equuleus, vain, comintern, asw, rambam,
# Nearest to joseph: monotone, mario, arya, retina, mission, halcyon, although, nationalized,
# Nearest to professional: loyola, ange, dockyard, grief, ammonite, nonpolar, munition, superhero,
# Nearest to primarily: insufficient, mangeshkar, typhus, echomail, buccaneer, kermanshah, adventures, mbox,
# Nearest to accepted: imlay, haec, rollercoaster, acknowledge, ashram, verbs, fart, boziz,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.4979 0.2196 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.5059 0.2253 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.4950 0.2328 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.4832 0.2222 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.5753 0.2171 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.4893 0.2273 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.4613 0.2291 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.4890 0.2467 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.4917 0.2279 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.4520 0.2276 sec/batch
# Nearest to this: of, be, the, is, and, in, to, it,
# Nearest to had: was, at, to, his, of, he, were, and,
# Nearest to use: with, to, but, waiver, which, these, its, kinesthetic,
# Nearest to at: of, to, the, from, and, on, in, was,
# Nearest to four: five, three, one, two, zero, six, eight, seven,
# Nearest to all: for, and, first, to, a, is, the, in,
# Nearest to can: is, be, which, it, a, that, this, and,
# Nearest to d: huron, plains, consonance, berrigan, whistleblower, stereotypically, cretan, conjecture,
# Nearest to hold: aspergillus, bilbo, flier, neogene, signifies, computing, came, romita,
# Nearest to road: grandmother, gon, micrometres, earthbound, galla, jumps, yaum, terrace,
# Nearest to running: reprise, christians, aleksey, intersects, monaro, politico, scuola, lydon,
# Nearest to quite: fuhito, galveston, equuleus, comintern, einstein, vain, streamline, microscope,
# Nearest to joseph: monotone, mario, retina, nationalized, lindow, halcyon, arya, euclid,
# Nearest to professional: loyola, nonpolar, dockyard, munition, ange, superhero, grief, antiquarian,
# Nearest to primarily: nitrile, mangeshkar, wow, insufficient, kermanshah, echomail, divisive, globus,
# Nearest to accepted: imlay, boziz, haec, acknowledge, verbs, cladogram, fart, mongolians,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.4477 0.2238 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.4611 0.2213 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.4543 0.2410 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.4512 0.2441 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.4466 0.2440 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.4700 0.2330 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.4345 0.2260 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.4482 0.2232 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.4363 0.2211 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.4377 0.2329 sec/batch
# Nearest to this: to, the, in, of, a, is, and, by,
# Nearest to had: often, the, was, of, this, a, from, to,
# Nearest to use: midian, drang, renouncing, with, arrigo, but, pyrrhic, to,
# Nearest to at: of, a, to, the, as, by, was, and,
# Nearest to four: three, one, five, two, six, eight, seven, zero,
# Nearest to all: of, the, and, in, to, a, is, not,
# Nearest to can: be, is, a, for, have, other, with, that,
# Nearest to d: whistleblower, plains, consonance, zaitsev, kavina, stereotypically, huron, berrigan,
# Nearest to hold: aspergillus, bilbo, sena, bosch, smallness, xlv, flier, detractors,
# Nearest to road: grandmother, gon, micrometres, galla, earthbound, taming, terrace, yaum,
# Nearest to running: monaro, reprise, aleksey, christians, balsam, steps, imt, unsuspecting,
# Nearest to quite: galveston, toilet, fuhito, streamline, enya, einstein, inhibit, jamo,
# Nearest to joseph: monotone, pucker, mario, retina, lindow, euclid, arya, kword,
# Nearest to professional: loyola, superhero, dockyard, nonpolar, munition, ange, pollo, microscope,
# Nearest to primarily: nitrile, kermanshah, metamorphoses, mangeshkar, buccaneer, guardians, echomail, hatter,
# Nearest to accepted: imlay, haec, acknowledge, boziz, tempted, cladogram, redundantly, flies,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.4292 0.2281 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.4335 0.2228 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.4280 0.2272 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.4424 0.2234 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.4583 0.2206 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.4575 0.2270 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.4218 0.2232 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.4420 0.2253 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.4411 0.2272 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.4411 0.2308 sec/batch
# Nearest to this: a, is, the, by, and, to, of, as,
# Nearest to had: damme, often, was, aswan, heretic, amati, heritage, by,
# Nearest to use: that, grocery, example, midian, gradius, arrigo, predicate, colonists,
# Nearest to at: was, in, with, the, of, to, by, from,
# Nearest to four: one, three, two, five, six, seven, zero, eight,
# Nearest to all: the, is, in, with, that, a, be, by,
# Nearest to can: is, be, a, it, are, for, to, that,
# Nearest to d: whistleblower, zaitsev, stereotypically, thompson, huron, plains, cpr, borgo,
# Nearest to hold: aspergillus, bilbo, sikhs, sena, detractors, xlv, smallness, sketch,
# Nearest to road: gon, grandmother, galla, earthbound, micrometres, mejia, taming, neyman,
# Nearest to running: monaro, aleksey, yup, scuola, pinguinus, reprise, imt, outcroppings,
# Nearest to quite: einstein, discussion, microscope, fuhito, galveston, vain, round, toilet,
# Nearest to joseph: monotone, euclid, retina, arya, pucker, mario, deutsch, kword,
# Nearest to professional: loyola, dockyard, superhero, antiquarian, ange, nonpolar, pollo, microscope,
# Nearest to primarily: nitrile, kermanshah, echomail, metamorphoses, wow, insufficient, tumulus, rik,
# Nearest to accepted: imlay, fart, haec, boziz, flies, redundantly, verbs, ukrainian,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.4494 0.2254 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.4132 0.2332 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.3991 0.2402 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.4001 0.2456 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.4050 0.2383 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.3821 0.2241 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4029 0.2304 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.4221 0.2500 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.4084 0.2490 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.3864 0.2565 sec/batch
# Nearest to this: of, the, and, to, is, a, with, by,
# Nearest to had: was, that, his, him, in, the, a, he,
# Nearest to use: it, is, exceeding, founded, unfriendly, insensitivity, valerie, smite,
# Nearest to at: with, to, was, the, his, s, he, of,
# Nearest to four: one, seven, three, two, five, eight, nine, six,
# Nearest to all: is, of, and, the, from, to, by, a,
# Nearest to can: is, be, are, some, adopts, this, a, such,
# Nearest to d: one, four, seven, eight, six, five, nine, american,
# Nearest to hold: bilbo, aspergillus, sikhs, smallness, xlv, could, detractors, sena,
# Nearest to road: galla, still, grandmother, earthbound, gon, mejia, neyman, taming,
# Nearest to running: monaro, expediency, reprise, formatting, aleksey, enlightened, yup, outcroppings,
# Nearest to quite: fuhito, round, einstein, microscope, universalists, meaningfully, applets, etat,
# Nearest to joseph: monotone, arya, euclid, retina, pucker, loyal, berated, eugen,
# Nearest to professional: loyola, dockyard, antiquarian, superhero, nonpolar, funded, recount, microscope,
# Nearest to primarily: nitrile, globus, eines, wow, tumulus, dispelling, echomail, rik,
# Nearest to accepted: imlay, speak, haec, cladogram, crawler, gemeinde, jiva, scrooge,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.4311 0.2597 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.4283 0.2537 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.4120 0.2505 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.4068 0.2525 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.4231 0.2505 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.3933 0.2589 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.4240 0.2377 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.4107 0.2418 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.4384 0.2543 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.4108 0.2372 sec/batch
# Nearest to this: to, the, in, be, is, that, by, and,
# Nearest to had: was, for, the, century, in, she, on, and,
# Nearest to use: jigger, several, finales, mitsuru, turtles, various, venomous, smite,
# Nearest to at: to, that, his, was, he, a, in, by,
# Nearest to four: one, seven, three, five, nine, six, eight, two,
# Nearest to all: are, from, and, there, the, ratings, annelids, if,
# Nearest to can: be, this, fact, a, to, is, in, that,
# Nearest to d: one, four, ecumenical, six, five, small, eight, american,
# Nearest to hold: bilbo, aspergillus, sikhs, smallness, detractors, horns, warwickshire, sketch,
# Nearest to road: galla, gon, grandmother, germantown, mejia, retelling, micrometres, earthbound,
# Nearest to running: monaro, expediency, outcroppings, enlightened, pinguinus, imitations, unsuspecting, insensible,
# Nearest to quite: anti, discussion, jamo, meaningfully, etat, einstein, zeroes, protesters,
# Nearest to joseph: monotone, arya, euclid, retina, pucker, loyal, mario, eugen,
# Nearest to professional: loyola, dockyard, antiquarian, microscope, superhero, recount, pollo, manipulated,
# Nearest to primarily: eines, nitrile, zhuyin, container, dispelling, echomail, blackadder, trenton,
# Nearest to accepted: imlay, haec, cladogram, speak, rollercoaster, boziz, la, commited,
# Epoch 2/10 Iteration: 23100 Avg. Training loss: 4.4039 0.2393 sec/batch
# Epoch 2/10 Iteration: 23200 Avg. Training loss: 4.3935 0.2490 sec/batch
# Epoch 2/10 Iteration: 23300 Avg. Training loss: 4.4086 0.2340 sec/batch
# Epoch 2/10 Iteration: 23400 Avg. Training loss: 4.4114 0.2445 sec/batch
# Epoch 2/10 Iteration: 23500 Avg. Training loss: 4.4076 0.2420 sec/batch
# Epoch 2/10 Iteration: 23600 Avg. Training loss: 4.4126 0.2449 sec/batch
# Epoch 2/10 Iteration: 23700 Avg. Training loss: 4.3797 0.2423 sec/batch
# Epoch 2/10 Iteration: 23800 Avg. Training loss: 4.3747 0.2451 sec/batch
# Epoch 2/10 Iteration: 23900 Avg. Training loss: 4.3604 0.2429 sec/batch
# Epoch 2/10 Iteration: 24000 Avg. Training loss: 4.3965 0.2435 sec/batch
# Nearest to this: the, to, a, and, that, in, be, of,
# Nearest to had: was, century, after, for, and, to, out, but,
# Nearest to use: smite, venomous, vympel, tefnut, midfielder, hundredth, viaduct, calves,
# Nearest to at: in, to, a, of, the, was, and, by,
# Nearest to four: one, three, five, two, seven, zero, six, eight,
# Nearest to all: are, can, the, indictment, keating, in, of, ratings,
# Nearest to can: be, a, to, and, or, of, most, in,
# Nearest to d: one, american, five, four, eight, seven, ecumenical, nine,
# Nearest to hold: bilbo, aspergillus, detractors, sikhs, smallness, neurotoxins, xlv, eastwards,
# Nearest to road: galla, grandmother, auxerre, gon, earthbound, mejia, terrace, micrometres,
# Nearest to running: unsuspecting, imitations, expediency, sabbat, aleksey, enlightened, politico, bipartite,
# Nearest to quite: meaningfully, einstein, discussion, rambam, enya, round, alfasi, lukashenko,
# Nearest to joseph: monotone, euclid, arya, retina, loyal, pucker, dreadlocks, nikola,
# Nearest to professional: loyola, superhero, dockyard, antiquarian, distinct, microscope, transceivers, recount,
# Nearest to primarily: eines, dignities, mbox, directv, tentacle, trenton, dispelling, grammatical,
# Nearest to accepted: imlay, cladogram, boziz, la, haec, ukrainian, formatted, commited,
# Epoch 2/10 Iteration: 24100 Avg. Training loss: 4.4045 0.2502 sec/batch
# Epoch 3/10 Iteration: 24200 Avg. Training loss: 4.3983 0.2217 sec/batch
# Epoch 3/10 Iteration: 24300 Avg. Training loss: 4.3953 0.2449 sec/batch
# Epoch 3/10 Iteration: 24400 Avg. Training loss: 4.3866 0.2477 sec/batch
# Epoch 3/10 Iteration: 24500 Avg. Training loss: 4.3787 0.2204 sec/batch
# Epoch 3/10 Iteration: 24600 Avg. Training loss: 4.3861 0.2202 sec/batch
# Epoch 3/10 Iteration: 24700 Avg. Training loss: 4.3626 0.2162 sec/batch
# Epoch 3/10 Iteration: 24800 Avg. Training loss: 4.3541 0.2134 sec/batch
# Epoch 3/10 Iteration: 24900 Avg. Training loss: 4.3138 0.2137 sec/batch
# Epoch 3/10 Iteration: 25000 Avg. Training loss: 4.3657 0.2174 sec/batch
# Nearest to this: that, to, s, be, and, the, a, it,
# Nearest to had: was, after, the, from, a, by, on, waxes,
# Nearest to use: zurich, smite, opposite, midfielder, burgesses, kwong, local, philistia,
# Nearest to at: to, the, a, of, in, and, was, for,
# Nearest to four: one, five, three, two, six, seven, eight, nine,
# Nearest to all: to, at, of, the, and, indictment, can, like,
# Nearest to can: be, are, have, to, all, and, or, that,
# Nearest to d: one, american, eight, seven, nine, four, six, five,
# Nearest to hold: bilbo, aspergillus, sikhs, criminals, eastwards, tamasheq, detractors, fit,
# Nearest to road: gon, earthbound, taming, galla, wet, terrace, cuboctahedron, grandmother,
# Nearest to running: unsuspecting, imitations, enlightened, index, monaro, voris, bipartite, execution,
# Nearest to quite: meaningfully, alfasi, alder, enya, zeroes, nomos, rambam, vain,
# Nearest to joseph: monotone, arya, loyal, pucker, euclid, retina, lindow, dreadlocks,
# Nearest to professional: loyola, distinct, dockyard, antiquarian, superhero, motu, manipulated, grasse,
# Nearest to primarily: dignities, mbox, tentacle, dispelling, metamorphoses, eines, directv, slipped,
# Nearest to accepted: cladogram, imlay, boziz, haec, formatted, accredited, marcionism, applicants,
# Epoch 3/10 Iteration: 25100 Avg. Training loss: 4.3766 0.2205 sec/batch
# Epoch 3/10 Iteration: 25200 Avg. Training loss: 4.3718 0.2415 sec/batch
# Epoch 3/10 Iteration: 25300 Avg. Training loss: 4.3775 0.2217 sec/batch
# Epoch 3/10 Iteration: 25400 Avg. Training loss: 4.3633 0.2318 sec/batch
# Epoch 3/10 Iteration: 25500 Avg. Training loss: 4.3470 0.2246 sec/batch
# Epoch 3/10 Iteration: 25600 Avg. Training loss: 4.3810 0.2583 sec/batch
# Epoch 3/10 Iteration: 25700 Avg. Training loss: 4.3607 0.2594 sec/batch
# Epoch 3/10 Iteration: 25800 Avg. Training loss: 4.3875 0.2322 sec/batch
# Epoch 3/10 Iteration: 25900 Avg. Training loss: 4.3639 0.2228 sec/batch
# Epoch 3/10 Iteration: 26000 Avg. Training loss: 4.3783 0.2391 sec/batch
# Nearest to this: that, and, the, to, be, a, by, s,
# Nearest to had: the, and, at, was, of, after, on, in,
# Nearest to use: hydras, social, kolbe, reminders, opposite, kwong, be, baring,
# Nearest to at: the, was, to, and, a, of, by, first,
# Nearest to four: one, five, two, seven, three, six, eight, nine,
# Nearest to all: the, of, and, s, was, jagiello, have, seq,
# Nearest to can: be, or, of, to, vague, and, are, huston,
# Nearest to d: american, one, eight, nine, six, seven, four, five,
# Nearest to hold: aspergillus, bilbo, tamasheq, ndm, information, detractors, outlawing, sikhs,
# Nearest to road: gon, cuboctahedron, retold, taming, wet, galla, terrace, legendary,
# Nearest to running: unsuspecting, execution, bipartite, asteraceae, alloy, partner, formatting, itso,
# Nearest to quite: meaningfully, alfasi, foodcrops, enya, round, inspectors, zeroes, sulfides,
# Nearest to joseph: monotone, pucker, loyal, arya, deutsch, euclid, dreadlocks, menstrual,
# Nearest to professional: loyola, distinct, superhero, dockyard, pde, configurable, grasse, manipulated,
# Nearest to primarily: dignities, slipped, trenton, metronome, directv, dispelling, rik, esprit,
# Nearest to accepted: marcionism, boziz, cladogram, gaians, cancellous, gory, fina, imlay,
# Epoch 3/10 Iteration: 26100 Avg. Training loss: 4.3676 0.2312 sec/batch
# Epoch 3/10 Iteration: 26200 Avg. Training loss: 4.3654 0.2273 sec/batch
# Epoch 3/10 Iteration: 26300 Avg. Training loss: 4.3655 0.2416 sec/batch
# Epoch 3/10 Iteration: 26400 Avg. Training loss: 4.3415 0.2303 sec/batch
# Epoch 3/10 Iteration: 26500 Avg. Training loss: 4.3598 0.2284 sec/batch
# Epoch 3/10 Iteration: 26600 Avg. Training loss: 4.3594 0.2278 sec/batch
# Epoch 3/10 Iteration: 26700 Avg. Training loss: 4.3666 0.2380 sec/batch
# Epoch 3/10 Iteration: 26800 Avg. Training loss: 4.3472 0.2359 sec/batch
# Epoch 3/10 Iteration: 26900 Avg. Training loss: 4.3926 0.2462 sec/batch
# Epoch 3/10 Iteration: 27000 Avg. Training loss: 4.3980 0.2642 sec/batch
# Nearest to this: to, and, the, of, be, a, s, in,
# Nearest to had: and, was, the, to, in, from, which, his,
# Nearest to use: burial, social, vivax, kwong, duras, aps, rigged, circus,
# Nearest to at: the, and, of, a, to, in, was, on,
# Nearest to four: one, three, five, seven, six, eight, nine, two,
# Nearest to all: an, the, is, clapp, of, are, calculating, also,
# Nearest to can: be, of, it, are, a, the, is, switchover,
# Nearest to d: american, one, eight, nine, six, four, five, french,
# Nearest to hold: smallness, iceland, celeb, mink, puddle, flexed, nathaniel, neurotoxins,
# Nearest to road: gon, facet, cuboctahedron, retold, member, terrace, versed, kitab,
# Nearest to running: execution, unsuspecting, imitations, christians, asteraceae, bipartite, infoplease, itso,
# Nearest to quite: alfasi, zeroes, praia, leroux, inspectors, round, nineties, tattoos,
# Nearest to joseph: loyal, pucker, arya, monotone, deutsch, phipps, eurocrypt, succeeds,
# Nearest to professional: pde, loyola, superhero, pollo, distinct, grasse, motu, ibf,
# Nearest to primarily: metronome, dignities, rik, hampering, evict, audits, slipped, mbox,
# Nearest to accepted: hv, fina, marcionism, imlay, aldus, cladogram, haec, angilbert,
# Epoch 3/10 Iteration: 27100 Avg. Training loss: 4.3573 0.2467 sec/batch
# Epoch 3/10 Iteration: 27200 Avg. Training loss: 4.3794 0.2258 sec/batch
# Epoch 3/10 Iteration: 27300 Avg. Training loss: 4.3633 0.2283 sec/batch
# Epoch 3/10 Iteration: 27400 Avg. Training loss: 4.3617 0.2284 sec/batch
# Epoch 3/10 Iteration: 27500 Avg. Training loss: 4.3744 0.2217 sec/batch
# Epoch 3/10 Iteration: 27600 Avg. Training loss: 4.3625 0.2165 sec/batch
# Epoch 3/10 Iteration: 27700 Avg. Training loss: 4.3990 0.2279 sec/batch
# Epoch 3/10 Iteration: 27800 Avg. Training loss: 4.3469 0.2450 sec/batch
# Epoch 3/10 Iteration: 27900 Avg. Training loss: 4.3735 0.2395 sec/batch
# Epoch 3/10 Iteration: 28000 Avg. Training loss: 4.3541 0.2288 sec/batch
# Nearest to this: the, to, is, not, a, that, it, in,
# Nearest to had: to, that, was, and, the, only, patristic, also,
# Nearest to use: used, provoke, demonstrations, systems, iceni, diabelli, ellesmere, ingham,
# Nearest to at: the, to, and, of, in, they, this, was,
# Nearest to four: five, one, three, six, seven, eight, two, nine,
# Nearest to all: the, in, to, it, and, is, with, was,
# Nearest to can: be, a, on, the, are, to, is, by,
# Nearest to d: american, six, french, whistleblower, hired, eight, nine, iconoclast,
# Nearest to hold: api, outlawing, madhya, flexed, bloodshed, iceland, smallness, celeb,
# Nearest to road: cuboctahedron, versed, gon, manu, lector, humanoids, retold, earthbound,
# Nearest to running: unsuspecting, execution, swinging, asteraceae, subroutine, undoing, risked, idris,
# Nearest to quite: zeroes, alfasi, tattoos, thebaid, nineties, praia, dvo, pleases,
# Nearest to joseph: arya, pucker, deutsch, loyal, monotone, eurocrypt, succeeds, menstrual,
# Nearest to professional: ibf, superhero, loyola, pollo, divergent, pde, distinct, lgiy,
# Nearest to primarily: rik, dignities, evict, lead, tensor, most, omnivorous, meditation,
# Nearest to accepted: hv, cladogram, pantheists, aldus, gory, jiva, accredited, formatting,
# Epoch 3/10 Iteration: 28100 Avg. Training loss: 4.3617 0.2407 sec/batch
# Epoch 3/10 Iteration: 28200 Avg. Training loss: 4.3529 0.2405 sec/batch
# Epoch 3/10 Iteration: 28300 Avg. Training loss: 4.3473 0.2379 sec/batch
# Epoch 3/10 Iteration: 28400 Avg. Training loss: 4.3391 0.2321 sec/batch
# Epoch 3/10 Iteration: 28500 Avg. Training loss: 4.3566 0.2271 sec/batch
# Epoch 3/10 Iteration: 28600 Avg. Training loss: 4.3631 0.2309 sec/batch
# Epoch 3/10 Iteration: 28700 Avg. Training loss: 4.3540 0.2290 sec/batch
# Epoch 3/10 Iteration: 28800 Avg. Training loss: 4.3493 0.2266 sec/batch
# Epoch 3/10 Iteration: 28900 Avg. Training loss: 4.3504 0.2294 sec/batch
# Epoch 3/10 Iteration: 29000 Avg. Training loss: 4.3331 0.2387 sec/batch
# Nearest to this: is, to, and, in, the, or, are, for,
# Nearest to had: was, to, and, the, were, he, for, his,
# Nearest to use: systems, used, of, has, brewed, the, as, in,
# Nearest to at: the, of, as, to, in, their, and, was,
# Nearest to four: three, one, five, six, two, seven, eight, zero,
# Nearest to all: the, and, to, of, in, as, a, it,
# Nearest to can: to, be, a, as, it, are, on, the,
# Nearest to d: american, one, nine, writer, eight, six, seven, five,
# Nearest to hold: outlawing, flexed, api, neurotoxins, celeb, infinitude, bloodshed, faked,
# Nearest to road: terrace, earthbound, facet, boulez, cuboctahedron, gon, taming, albertine,
# Nearest to running: execution, sabbat, tarragona, nasrani, asteraceae, micronational, swinging, undoing,
# Nearest to quite: pleases, pulsar, tattoos, round, applets, mallorca, zeroes, sulfides,
# Nearest to joseph: arya, deutsch, loyal, pucker, menstrual, unexploited, monotone, debater,
# Nearest to professional: ibf, superhero, divergent, pollo, bogie, incorporated, specifier, dockyard,
# Nearest to primarily: rik, most, envelopes, ecclesiastica, lead, dignities, metronome, tensor,
# Nearest to accepted: cladogram, subconscious, aldus, convalescence, formatting, hv, imlay, haec,
# Epoch 3/10 Iteration: 29100 Avg. Training loss: 4.3370 0.2438 sec/batch
# Epoch 3/10 Iteration: 29200 Avg. Training loss: 4.3507 0.2330 sec/batch
# Epoch 3/10 Iteration: 29300 Avg. Training loss: 4.3478 0.2339 sec/batch
# Epoch 3/10 Iteration: 29400 Avg. Training loss: 4.3420 0.2267 sec/batch
# Epoch 3/10 Iteration: 29500 Avg. Training loss: 4.3407 0.2334 sec/batch
# Epoch 3/10 Iteration: 29600 Avg. Training loss: 4.3356 0.2367 sec/batch
# Epoch 3/10 Iteration: 29700 Avg. Training loss: 4.3340 0.2342 sec/batch
# Epoch 3/10 Iteration: 29800 Avg. Training loss: 4.3358 0.2397 sec/batch
# Epoch 3/10 Iteration: 29900 Avg. Training loss: 4.3392 0.2313 sec/batch
# Epoch 3/10 Iteration: 30000 Avg. Training loss: 4.3454 0.2218 sec/batch
# Nearest to this: the, to, of, a, and, in, are, is,
# Nearest to had: was, by, the, to, of, as, in, technica,
# Nearest to use: retirees, agong, of, used, this, quests, known, a,
# Nearest to at: of, the, in, as, and, was, to, two,
# Nearest to four: one, three, six, five, seven, eight, two, zero,
# Nearest to all: are, and, the, that, of, to, with, for,
# Nearest to can: be, is, to, are, a, example, the, which,
# Nearest to d: american, writer, one, b, nine, seats, abortifacient, burnout,
# Nearest to hold: myosin, api, somersault, trophyless, vulgare, militarism, kinder, nightclubs,
# Nearest to road: treasures, gon, albertine, facet, retold, cuboctahedron, terrace, boulez,
# Nearest to running: execution, nasrani, sabbat, concubine, tenet, asteraceae, secular, doraemons,
# Nearest to quite: zeroes, applets, pleases, low, upgrade, round, vain, wretched,
# Nearest to joseph: deutsch, arya, loyal, menstrual, symphonic, retina, effendi, succeeds,
# Nearest to professional: ibf, pollo, superhero, divergent, incorporated, antiquarian, twinned, victors,
# Nearest to primarily: rik, liban, ecclesiastica, jamil, envelopes, esprit, excretory, tensor,
# Nearest to accepted: aldus, formatting, hv, cladogram, subconscious, subcategory, bwv, comedian,
# Epoch 3/10 Iteration: 30100 Avg. Training loss: 4.3660 0.2280 sec/batch
# Epoch 3/10 Iteration: 30200 Avg. Training loss: 4.3486 0.2236 sec/batch
# Epoch 3/10 Iteration: 30300 Avg. Training loss: 4.3423 0.2290 sec/batch
# Epoch 3/10 Iteration: 30400 Avg. Training loss: 4.3334 0.2401 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
